# %% [markdown]
# ### Forecasting with SARIMAX for the whole dataset

# %%
import warnings
warnings.filterwarnings('ignore')

import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_percentage_error as mape
import statsmodels.api as sm
import pickle

# %%
order = (5, 1, 1)  # p, d, q
seasonal_order = (1, 1, 1, 7) # P, D, Q, m

# %%
# all data file
with open('all_data.pkl', 'rb') as f:
    df = pickle.load(f)
# df.head(2)

# %%
# returns neighbors node names for a given node
def get_neighbors(data, n):
    t = data[data['node']==n]['neib_node'].values.flatten().tolist()[0]
    return t

# %%
# returns prices list for a give node
def get_prices(data, n):
    prices_cols = data.columns[4:]
    t = data[data['node']==n][prices_cols].values.flatten().tolist()
    return t

# %%
# Forecasts and returns RMSE and MAPE for a provided dataframe without neighbors
def forecast_SARIMAX(data, forecast_days):
    data = data.copy()
    
    # test/train split
    train, test = data[:-forecast_days], data[-forecast_days:] 
    # model
    model_fit = sm.tsa.statespace.SARIMAX(endog=train['price'], 
                                          order=order, 
                                          seasonal_order = seasonal_order, 
                                         enforce_stationarity=False
                                         # enforce_invertibility=False
                                         ).fit()
    yhat = model_fit.forecast(forecast_days)
    # accuracy metrix
    rmse_res = mse(test['price'], yhat, squared=False)
    mape_res = mape(test['price'], yhat)
    
    return round(rmse_res, 2), round(mape_res, 3)

# %%
# Forecasts and returns RMSE and MAPE for a provided dataframe with neightbors
def forecast_SARIMAX_lag(data, forecast_days, lag=366, neighbors=[]):
    data = data.copy()
    
    #creating lag columns for neibghors prices and shifting
    for neib in neighbors:
        data[neib] = data[neib].shift(lag)
    # removing NaNs
    data.dropna(inplace = True)
    data.reset_index(inplace = True, drop=True)

    # test/train split
    train, test = data[:-forecast_days], data[-forecast_days:] 
    # model
    model_fit = sm.tsa.statespace.SARIMAX(endog=train['price'], 
                                          exog=train[neighbors],
                                          order=order, 
                                          seasonal_order = seasonal_order, 
                                         enforce_stationarity=False).fit()
    yhat = model_fit.forecast(forecast_days, exog=test[neighbors])
    # accuracy metrix
    rmse_res = mse(test['price'], yhat, squared=False)
    mape_res = mape(test['price'], yhat)
    
    return round(rmse_res, 2), round(mape_res, 3)

# %%
warnings.filterwarnings('ignore')
# settings
number_of_neighbors = 10
list_of_nodes = df['node'].tolist() # [100419] #
dates = pd.date_range(start='2019-12-05', periods = 1429)
forecast_size=30

#resulting dict and aux counters
# result = {'node':[], 'RMSE_1':[], 'MAPE_1':[], 'RMSE_2':[], 'MAPE_2':[]}
with open('all_data_SAR_10_neighb.pkl', 'rb') as f:
    result = pickle.load(f)

balance = 0 # 
k=len(list_of_nodes)

for node in list_of_nodes:
#     print(node)
    if (node in result['node']):
        print("skipping:", node)
        k-=1
        continue
    if (node in [402159, 403038, 403987]):
        continue
        # skipping faulty node
    
   
    # print("working for:", node)
    prices = get_prices(df, node)
    curr_df = pd.DataFrame(data = {'date':dates, 'price':prices})
    # add neighbors
    neighbors = get_neighbors(df, node)[:number_of_neighbors]
    neighb_to_remove = []
    for neighbor in neighbors:
        p = get_prices(df, neighbor)
        if (len(p) == 1429):
            curr_df[neighbor] = p
        else: 
            neighb_to_remove.append(neighbor)
    neighbors = list(set(neighbors) - set(neighb_to_remove))
    # curr_df.dropna()

    for neighbor in neighbors:
        curr_df[neighbor] = get_prices(df, neighbor)
        
    #forecast w/o neighbors
    rmse_1, mape_1 = forecast_SARIMAX (curr_df, forecast_size)
    #print("RMSE_1:", rmse_1, "MAPE_1:", mape_1)
    
    #forecast with neighbors
    rmse_2, mape_2 = forecast_SARIMAX_lag(curr_df, forecast_size, neighbors = neighbors)
    #print("RMSE_2:", rmse_2, "MAPE_2:", mape_2)
    
    result['node'].append(node)
    result['RMSE_1'].append(rmse_1)
    result['MAPE_1'].append(mape_1)
    result['RMSE_2'].append(rmse_2)
    result['MAPE_2'].append(mape_2)
    # interim results
    if (rmse_1 > rmse_2):
        balance +=1
    else: balance-=1
        
    k-=1   
    print("Node:",str(node) + " --> k:"+ str(k) + " --> Success:"+str(balance)+"   ", end="\r")
# Out:
# skipping: 100001
# skipping: 100003
# skipping: 100004
# skipping: 100005
# skipping: 100006
# skipping: 100007
# skipping: 100008
# skipping: 100009
# skipping: 100010
# skipping: 100011
# skipping: 100012
# skipping: 100013
# skipping: 100015
# skipping: 100016
# skipping: 100017
# skipping: 100018
# skipping: 100019
# skipping: 100020
# skipping: 100021
# skipping: 100022
# skipping: 100023
# skipping: 100024
# skipping: 100025
# skipping: 100026
# skipping: 100027
# skipping: 100028
# skipping: 100029
# skipping: 100030
# skipping: 100031
# skipping: 100032
# skipping: 100033
# skipping: 100035
# skipping: 100036
# skipping: 100037
# skipping: 100038
# skipping: 100039
# skipping: 100040
# skipping: 100041
# skipping: 100042
# skipping: 100043
# skipping: 100044
# skipping: 100045
# skipping: 100046
# skipping: 100047
# skipping: 100048
# skipping: 100049
# skipping: 100050
# skipping: 100051
# skipping: 100052
# skipping: 100053
# skipping: 100054
# skipping: 100055
# skipping: 100056
# skipping: 100057
# skipping: 100058
# skipping: 100059
# skipping: 100060
# skipping: 100061
# skipping: 100062
# skipping: 100063
# skipping: 100064
# skipping: 100065
# skipping: 100066
# skipping: 100067
# skipping: 100068
# skipping: 100069
# skipping: 100070
# skipping: 100072
# skipping: 100073
# skipping: 100074
# skipping: 100075
# skipping: 100076
# skipping: 100077
# skipping: 100078
# skipping: 100079
# skipping: 100080
# skipping: 100081
# skipping: 100082
# skipping: 100083
# skipping: 100084
# skipping: 100085
# skipping: 100086
# skipping: 100087
# skipping: 100088
# skipping: 100089
# skipping: 100090
# skipping: 100091
# skipping: 100092
# skipping: 100093
# skipping: 100094
# skipping: 100095
# skipping: 100096
# skipping: 100097
# skipping: 100098
# skipping: 100099
# skipping: 100101
# skipping: 100102
# skipping: 100103
# skipping: 100104
# skipping: 100105
# skipping: 100106
# skipping: 100107
# skipping: 100108
# skipping: 100109
# skipping: 100110
# skipping: 100111
# skipping: 100112
# skipping: 100113
# skipping: 100114
# skipping: 100115
# skipping: 100116
# skipping: 100117
# skipping: 100118
# skipping: 100119
# skipping: 100120
# skipping: 100121
# skipping: 100122
# skipping: 100124
# skipping: 100125
# skipping: 100126
# skipping: 100127
# skipping: 100128
# skipping: 100129
# skipping: 100130
# skipping: 100131
# skipping: 100132
# skipping: 100133
# skipping: 100134
# skipping: 100135
# skipping: 100138
# skipping: 100139
# skipping: 100140
# skipping: 100141
# skipping: 100142
# skipping: 100143
# skipping: 100144
# skipping: 100145
# skipping: 100146
# skipping: 100147
# skipping: 100148
# skipping: 100149
# skipping: 100150
# skipping: 100151
# skipping: 100152
# skipping: 100153
# skipping: 100154
# skipping: 100156
# skipping: 100157
# skipping: 100158
# skipping: 100159
# skipping: 100160
# skipping: 100161
# skipping: 100162
# skipping: 100163
# skipping: 100164
# skipping: 100165
# skipping: 100166
# skipping: 100167
# skipping: 100168
# skipping: 100169
# skipping: 100170
# skipping: 100171
# skipping: 100172
# skipping: 100173
# skipping: 100174
# skipping: 100175
# skipping: 100177
# skipping: 100178
# skipping: 100179
# skipping: 100181
# skipping: 100182
# skipping: 100184
# skipping: 100185
# skipping: 100187
# skipping: 100188
# skipping: 100189
# skipping: 100190
# skipping: 100191
# skipping: 100192
# skipping: 100193
# skipping: 100194
# skipping: 100195
# skipping: 100196
# skipping: 100197
# skipping: 100198
# skipping: 100199
# skipping: 100201
# skipping: 100202
# skipping: 100203
# skipping: 100204
# skipping: 100205
# skipping: 100206
# skipping: 100207
# skipping: 100208
# skipping: 100209
# skipping: 100210
# skipping: 100211
# skipping: 100212
# skipping: 100213
# skipping: 100214
# skipping: 100215
# skipping: 100216
# skipping: 100217
# skipping: 100218
# skipping: 100219
# skipping: 100220
# skipping: 100221
# skipping: 100222
# skipping: 100223
# skipping: 100224
# skipping: 100225
# skipping: 100226
# skipping: 100227
# skipping: 100228
# skipping: 100229
# skipping: 100230
# skipping: 100231
# skipping: 100232
# skipping: 100233
# skipping: 100235
# skipping: 100236
# skipping: 100237
# skipping: 100239
# skipping: 100240
# skipping: 100241
# skipping: 100242
# skipping: 100243
# skipping: 100244
# skipping: 100245
# skipping: 100246
# skipping: 100247
# skipping: 100248
# skipping: 100249
# skipping: 100250
# skipping: 100251
# skipping: 100252
# skipping: 100253
# skipping: 100254
# skipping: 100255
# skipping: 100259
# skipping: 100261
# skipping: 100262
# skipping: 100263
# skipping: 100264
# skipping: 100265
# skipping: 100267
# skipping: 100268
# skipping: 100269
# skipping: 100270
# skipping: 100271
# skipping: 100272
# skipping: 100273
# skipping: 100277
# skipping: 100280
# skipping: 100281
# skipping: 100282
# skipping: 100283
# skipping: 100284
# skipping: 100285
# skipping: 100286
# skipping: 100287
# skipping: 100288
# skipping: 100289
# skipping: 100290
# skipping: 100291
# skipping: 100292
# skipping: 100293
# skipping: 100294
# skipping: 100301
# skipping: 100302
# skipping: 100303
# skipping: 100304
# skipping: 100305
# skipping: 100306
# skipping: 100307
# skipping: 100308
# skipping: 100309
# skipping: 100310
# skipping: 100311
# skipping: 100312
# skipping: 100313
# skipping: 100315
# skipping: 100316
# skipping: 100317
# skipping: 100319
# skipping: 100320
# skipping: 100321
# skipping: 100322
# skipping: 100323
# skipping: 100324
# skipping: 100325
# skipping: 100326
# skipping: 100327
# skipping: 100328
# skipping: 100329
# skipping: 100330
# skipping: 100331
# skipping: 100332
# skipping: 100333
# skipping: 100334
# skipping: 100335
# skipping: 100337
# skipping: 100338
# skipping: 100339
# skipping: 100342
# skipping: 100346
# skipping: 100364
# skipping: 100365
# skipping: 100366
# skipping: 100367
# skipping: 100368
# skipping: 100380
# skipping: 100381
# skipping: 100383
# skipping: 100384
# skipping: 100385
# skipping: 100391
# skipping: 100392
# skipping: 100401
# skipping: 100402
# skipping: 100403
# skipping: 100404
# skipping: 100405
# skipping: 100406
# skipping: 100407
# skipping: 100408
# skipping: 100409
# skipping: 100410
# skipping: 100411
# skipping: 100412
# skipping: 100413
# skipping: 100414
# skipping: 100415
# skipping: 100416
# skipping: 100417
# skipping: 100418
# skipping: 100419
# skipping: 100420
# skipping: 100421
# skipping: 100422
# skipping: 100423
# skipping: 100424
# skipping: 100425
# skipping: 100426
# skipping: 100427
# skipping: 100428
# skipping: 100429
# skipping: 100430
# skipping: 100431
# skipping: 100432
# skipping: 100433
# skipping: 100434
# skipping: 100435
# skipping: 100436
# skipping: 100437
# skipping: 100438
# skipping: 100439
# skipping: 100440
# skipping: 100441
# skipping: 100442
# skipping: 100443
# skipping: 100444
# skipping: 100445
# skipping: 100446
# skipping: 100447
# skipping: 100448
# skipping: 100449
# skipping: 100450
# skipping: 100451
# skipping: 100452
# skipping: 100453
# skipping: 100454
# skipping: 100455
# skipping: 100456
# skipping: 100457
# skipping: 100458
# skipping: 100459
# skipping: 100460
# skipping: 100461
# skipping: 100462
# skipping: 100463
# skipping: 100464
# skipping: 100465
# skipping: 100466
# skipping: 100467
# skipping: 100468
# skipping: 100469
# skipping: 100470
# skipping: 100471
# skipping: 100472
# skipping: 100474
# skipping: 100475
# skipping: 100476
# skipping: 100477
# skipping: 100478
# skipping: 100479
# skipping: 100480
# skipping: 100481
# skipping: 100482
# skipping: 100483
# skipping: 100484
# skipping: 100485
# skipping: 100486
# skipping: 100487
# skipping: 100488
# skipping: 100489
# skipping: 100490
# skipping: 100492
# skipping: 100493
# skipping: 100494
# skipping: 100495
# skipping: 100496
# skipping: 100499
# skipping: 100501
# skipping: 100502
# skipping: 100503
# skipping: 100504
# skipping: 100506
# skipping: 100507
# skipping: 100508
# skipping: 100511
# skipping: 100512
# skipping: 100515
# skipping: 100518
# skipping: 100520
# skipping: 100521
# skipping: 100524
# skipping: 100525
# skipping: 100526
# skipping: 100527
# skipping: 100528
# skipping: 100529
# skipping: 100530
# skipping: 100531
# skipping: 100532
# skipping: 100533
# skipping: 100534
# skipping: 100540
# skipping: 100541
# skipping: 100542
# skipping: 100544
# skipping: 100545
# skipping: 100550
# skipping: 100551
# skipping: 100552
# skipping: 100553
# skipping: 100554
# skipping: 100555
# skipping: 100561
# skipping: 100562
# skipping: 100563
# skipping: 100601
# skipping: 100602
# skipping: 100603
# skipping: 100610
# skipping: 100611
# skipping: 100612
# skipping: 100613
# skipping: 100617
# skipping: 100618
# skipping: 100626
# skipping: 100627
# skipping: 100628
# skipping: 100629
# skipping: 100631
# skipping: 100632
# skipping: 100634
# skipping: 100635
# skipping: 100636
# skipping: 100637
# skipping: 100638
# skipping: 100639
# skipping: 100640
# skipping: 100643
# skipping: 100644
# skipping: 100645
# skipping: 100646
# skipping: 100647
# skipping: 100650
# skipping: 100651
# skipping: 100652
# skipping: 100653
# skipping: 100654
# skipping: 100655
# skipping: 100656
# skipping: 100657
# skipping: 100658
# skipping: 100659
# skipping: 100660
# skipping: 100701
# skipping: 100702
# skipping: 100703
# skipping: 100704
# skipping: 100706
# skipping: 100707
# skipping: 100708
# skipping: 100709
# skipping: 100710
# skipping: 100711
# skipping: 100712
# skipping: 100713
# skipping: 100714
# skipping: 100715
# skipping: 100716
# skipping: 100717
# skipping: 100718
# skipping: 100719
# skipping: 100720
# skipping: 100721
# skipping: 100722
# skipping: 100723
# skipping: 100724
# skipping: 100725
# skipping: 100726
# skipping: 100727
# skipping: 100728
# skipping: 100733
# skipping: 100735
# skipping: 100736
# skipping: 100737
# skipping: 100738
# skipping: 100739
# skipping: 100740
# skipping: 100741
# skipping: 100742
# skipping: 100743
# skipping: 100744
# skipping: 100745
# skipping: 100746
# skipping: 100747
# skipping: 100748
# skipping: 100749
# skipping: 100750
# skipping: 100751
# skipping: 100752
# skipping: 100753
# skipping: 100754
# skipping: 100755
# skipping: 100756
# skipping: 100757
# skipping: 100758
# skipping: 100759
# skipping: 100760
# skipping: 100761
# skipping: 100762
# skipping: 100763
# skipping: 100764
# skipping: 100765
# skipping: 100767
# skipping: 100768
# skipping: 100769
# skipping: 100770
# skipping: 100771
# skipping: 100772
# skipping: 100773
# skipping: 100774
# skipping: 100775
# skipping: 100776
# skipping: 100777
# skipping: 100778
# skipping: 100779
# skipping: 100780
# skipping: 100781
# skipping: 100782
# skipping: 100783
# skipping: 100784
# skipping: 100785
# skipping: 100786
# skipping: 100787
# skipping: 100788
# skipping: 100789
# skipping: 100790
# skipping: 100791
# skipping: 100792
# skipping: 100793
# skipping: 100794
# skipping: 100795
# skipping: 100796
# skipping: 100797
# skipping: 100798
# skipping: 100799
# skipping: 100801
# skipping: 100802
# skipping: 100803
# skipping: 100804
# skipping: 100805
# skipping: 100806
# skipping: 100807
# skipping: 100808
# skipping: 100809
# skipping: 100810
# skipping: 100811
# skipping: 100812
# skipping: 100813
# skipping: 100814
# skipping: 100815
# skipping: 100816
# skipping: 100817
# skipping: 100818
# skipping: 100819
# skipping: 100820
# skipping: 100821
# skipping: 100822
# skipping: 100823
# skipping: 100824
# skipping: 100825
# skipping: 100826
# skipping: 100827
# skipping: 100828
# skipping: 100829
# skipping: 100830
# skipping: 403922
# skipping: 403923
# skipping: 403924
# skipping: 403925
# skipping: 403926
# skipping: 403927
# skipping: 403928
# skipping: 403929
# skipping: 403930
# skipping: 403931
# skipping: 403932
# skipping: 403934
# skipping: 403935
# skipping: 403936
# skipping: 403937
# skipping: 403938
# skipping: 403942
# skipping: 403943
# skipping: 403944
# skipping: 403946
# skipping: 403947
# skipping: 403948
# skipping: 403949
# skipping: 403965
# skipping: 403966
# skipping: 403967
# skipping: 403968
# skipping: 403974
# skipping: 403975
# skipping: 403976
# skipping: 403978
# skipping: 403979
# skipping: 403980
# skipping: 403982
# skipping: 403983
# skipping: 403984
# skipping: 403985
# skipping: 403986
# Node: 404122 --> k:2906 --> Success:8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-99f36e21d5cb> in <module>
#      48
#      49     #forecast with neighbors
# ---> 50     rmse_2, mape_2 = forecast_SARIMAX_lag(curr_df, forecast_size, neighbors = neighbors)
#      51     #print("RMSE_2:", rmse_2, "MAPE_2:", mape_2)
#      52
#
# <ipython-input-7-31665ad92f29> in forecast_SARIMAX_lag(data, forecast_days, lag, neighbors)
#      13     train, test = data[:-forecast_days], data[-forecast_days:]
#      14     # model
# ---> 15     model_fit = sm.tsa.statespace.SARIMAX(endog=train['price'],
#      16                                           exog=train[neighbors],
#      17                                           order=order,
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     726             else:
#     727                 func = self.smooth
# --> 728             res = func(mlefit.params, transformed=False, includes_fixed=False,
#     729                        cov_type=cov_type, cov_kwds=cov_kwds)
#     730
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in smooth(self, params, transformed, includes_fixed, complex_step, cov_type, cov_kwds, return_ssm, results_class, results_wrapper_class, **kwargs)
#     887
#     888         # Wrap in a results object
# --> 889         return self._wrap_results(params, result, return_ssm, cov_type,
#     890                                   cov_kwds, results_class,
#     891                                   results_wrapper_class)
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in _wrap_results(self, params, result, return_raw, cov_type, cov_kwds, results_class, wrapper_class)
#     786                 wrapper_class = self._res_classes['fit'][1]
#     787
# --> 788             res = results_class(self, params, result, **result_kwargs)
#     789             result = wrapper_class(res)
#     790         return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in __init__(self, model, params, filter_results, cov_type, **kwargs)
#    1804     def __init__(self, model, params, filter_results, cov_type=None,
#    1805                  **kwargs):
# -> 1806         super(SARIMAXResults, self).__init__(model, params, filter_results,
#    1807                                              cov_type, **kwargs)
#    1808
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in __init__(self, model, params, results, cov_type, cov_kwds, **kwargs)
#    2371         try:
#    2372             self._rank = None
# -> 2373             self._get_robustcov_results(cov_type=cov_type, use_self=True,
#    2374                                         **cov_kwds)
#    2375         except np.linalg.LinAlgError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in _get_robustcov_results(self, cov_type, **kwargs)
#    2601                                                 approx_type=approx_type_str)
#    2602         elif self.cov_type == 'opg':
# -> 2603             res.cov_params_default = res.cov_params_opg
#    2604             res.cov_kwds['description'] = descriptions['OPG'].format(
#    2605                                                 approx_type=approx_type_str)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in cov_params_opg(self)
#    2731         product of gradients method.
#    2732         """
# -> 2733         return self._cov_params_opg(self._cov_approx_complex_step,
#    2734                                     self._cov_approx_centered)
#    2735
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in _cov_params_opg(self, approx_complex_step, approx_centered)
#    2698
#    2699     def _cov_params_opg(self, approx_complex_step=True, approx_centered=False):
# -> 2700         evaluated_hessian = self.nobs_effective * self.model._hessian_opg(
#    2701             self.params, transformed=True, includes_fixed=True,
#    2702             approx_complex_step=approx_complex_step,
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in _hessian_opg(self, params, **kwargs)
#    1540         information matrix
#    1541         """
# -> 1542         return -self.opg_information_matrix(params, **kwargs)
#    1543
#    1544     def _hessian_finite_difference(self, params, approx_centered=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in opg_information_matrix(self, params, transformed, includes_fixed, approx_complex_step, **kwargs)
#    1227                              " with untransformed parameters.")
#    1228
# -> 1229         score_obs = self.score_obs(params, transformed=transformed,
#    1230                                    includes_fixed=includes_fixed,
#    1231                                    approx_complex_step=approx_complex_step,
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in score_obs(self, params, method, transformed, includes_fixed, approx_complex_step, approx_centered, **kwargs)
#    1446             epsilon = _get_epsilon(params, 2., None, len(params))
#    1447             kwargs['complex_step'] = True
# -> 1448             score = approx_fprime_cs(params, self.loglikeobs, epsilon=epsilon,
#    1449                                      kwargs=kwargs)
#    1450         elif method == 'approx':
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\numdiff.py in approx_fprime_cs(x, f, epsilon, args, kwargs)
#     249     increments = np.identity(n) * 1j * epsilon
#     250     # TODO: see if this can be vectorized, but usually dim is small
# --> 251     partials = [f(x+ih, *args, **kwargs).imag / epsilon[i]
#     252                 for i, ih in enumerate(increments)]
#     253
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\numdiff.py in <listcomp>(.0)
#     249     increments = np.identity(n) * 1j * epsilon
#     250     # TODO: see if this can be vectorized, but usually dim is small
# --> 251     partials = [f(x+ih, *args, **kwargs).imag / epsilon[i]
#     252                 for i, ih in enumerate(increments)]
#     253
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in loglikeobs(self, params, transformed, includes_fixed, complex_step, **kwargs)
#     986                     complex_step=complex_step)
#     987
# --> 988         return self.ssm.loglikeobs(complex_step=complex_step, **kwargs)
#     989
#     990     def simulation_smoother(self, simulation_output=None, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in loglikeobs(self, **kwargs)
#    1066                 'conserve_memory',
#    1067                 MEMORY_CONSERVE ^ (MEMORY_NO_FORECAST | MEMORY_NO_LIKELIHOOD))
# -> 1068         kfilter = self._filter(**kwargs)
#    1069         llf_obs = np.array(kfilter.loglikelihood, copy=True)
#    1070         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#
# KeyboardInterrupt:

# %%
node

# %%
with open('all_data_SAR_10_neighb.pkl', 'wb') as f:
    pickle.dump(result, f)

# %%
df = pd.DataFrame.from_dict(result)

# %%
df['RMSE_1'].mean(), df['RMSE_2'].mean()
# Out:
# (213.23394729618448, 220.29946198188307)
